# %% [markdown]
# # Dike Model Analysis

# %%
# import libraries
from ema_workbench import load_results
from ema_workbench.analysis import pairs_plotting
import matplotlib.pyplot as plt

# %% [markdown]
# ## Visual Analysis

# %%
experiments1, outcomes1 = load_results('./results/openexplor_problem1.tar.gz')

# %%
fig, axes = pairs_plotting.pairs_scatter(experiments1, outcomes1)
fig.set_figheight(15)
fig.set_figwidth(15)
plt.show()

# %%
experiments2, outcomes2 = load_results('./results/openexplor_problem2.tar.gz')

# %%
fig, axes = pairs_plotting.pairs_scatter(experiments2, outcomes2)
fig.set_figheight(15)
fig.set_figwidth(15)
plt.show()

# %%
experiments3, outcomes3 = load_results('./results/openexplor_problem3.tar.gz')

# %%
fig, axes = pairs_plotting.pairs_scatter(experiments3, outcomes3)
fig.set_figheight(15)
fig.set_figwidth(15)
plt.show()
